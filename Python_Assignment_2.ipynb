# %% [markdown]
# <a href="https://colab.research.google.com/github/Revathi2990/Excel-coding-challenge/blob/main/Python_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LIST**

# %%
age_list=[24,25,26,27,28]
age_list
# Out:
# [24, 25, 26, 27, 28]

# %%
print(type(age_list))
# Out:
# <class 'list'>

# %%
name_list=['gayathiri','aishu','revathi','divya','maha']
name_list
# Out:
# ['gayathiri', 'aishu', 'revathi', 'divya', 'maha']

# %%
print(type(name_list))
# Out:
# <class 'list'>

# %%
age_list[0]
# Out:
# 24

# %%
name_list[:5]
# Out:
# ['gayathiri', 'aishu', 'revathi', 'divya', 'maha']

# %%
age_list.insert(2,30)
age_list
# Out:
# [24, 25, 30, 30, 26, 27, 28]

# %%
name_list.append('yazhini')
name_list
# Out:
# ['gayathiri', 'aishu', 'revathi', 'divya', 'maha', 'yazhini']

# %%
print(name_list)
# Out:
# ['gayathiri', 'aishu', 'revathi', 'divya', 'maha', 'yazhini']

# %%
name_list.remove('yazhini')

# %%
print(name_list)
# Out:
# ['gayathiri', 'aishu', 'revathi', 'divya', 'maha']

# %%
age_list.pop()
age_list
# Out:
# [24, 25, 30, 30, 26]

# %%
age_list.extend([29,30,26])
age_list
# Out:
# [24, 25, 30, 30, 26, 29, 30, 26, 29, 30, 26]

# %%
age_list.sort(reverse=True)
age_list
# Out:
# [30, 30, 30, 30, 29, 29, 26, 26, 26, 25, 24]

# %%
min(age_list)
# Out:
# 24

# %%
max(age_list)
# Out:
# 30

# %%
age_list
# Out:
# [30, 30, 30, 30, 29, 29, 26, 26, 26, 25, 24]

# %%
print(age_list[0])
# Out:
# 30

# %%
print(age_list[-1])
# Out:
# 24

# %%
name_list
# Out:
# ['gayathiri', 'aishu', 'revathi', 'divya', 'maha']

# %%
print(name_list[2:5])
# Out:
# ['revathi', 'divya', 'maha']

# %%
print(name_list[::-1])
# Out:
# ['maha', 'divya', 'revathi', 'aishu', 'gayathiri']

# %% [markdown]
# **DICTIONARY**

# %%
student_marks = {
    "Alex": 85,
    "Bella": 92,
    "Chris": 78,
    "Diana": 95,
    "Evan": 64
}

# %%
student_marks
# Out:
# {'Alex': 85, 'Bella': 92, 'Chris': 78, 'Diana': 95, 'Evan': 64}

# %%
student_marks = {
    "101": {"name": "Alice", "mark": 85},
    "102": {"name": "Bob", "mark": 92},
    "103": {"name": "Charlie", "mark": 78}
}

# %%
# Choose a specific student's roll number to search
target_roll = "102"

# %%
target_roll
# Out:
# '102'

# %%
student_marks["Janani"] = 80

# %%
student_marks
# Out:
# {'101': {'name': 'Alice', 'mark': 85},
#  '102': {'name': 'Bob', 'mark': 92},
#  '103': {'name': 'Charlie', 'mark': 78},
#  'Janani': 80}

# %%
student_marks = {"Alice": 75, "Bob": 90, "Charlie": 68}
student_marks["Bob"] = 82

# %%
print(student_marks)
# Out:
# {'Alice': 75, 'Bob': 82, 'Charlie': 68}

# %%
print("keys",student_marks.keys())
# Out:
# keys dict_keys(['Alice', 'Bob', 'Charlie'])

# %%
print('values,student_marks.values()')
print(student_marks)
# Out:
# values,student_marks.values()
# {'Alice': 75, 'Bob': 82, 'Charlie': 68}

# %%
print('items,student_marks.items()')
print(student_marks)
# Out:
# items,student_marks.items()
# {'Alice': 75, 'Bob': 82, 'Charlie': 68}

# %% [markdown]
# **SET (OPERATIONS)**

# %%
my_set=['a','e','i','o','u','a','a','i']
unique_set=set(my_set)
print(unique_set)
# Out:
# {'u', 'e', 'o', 'i', 'a'}

# %%
print(my_set)
# Out:
# ['a', 'e', 'i', 'o', 'u', 'a', 'a', 'i']

# %%
try:
    my_set = {1, 2, 3, 4, 5}
    my_set[4] = 's'
except TypeError as e:
    print(f"Error caught: {e}")
# Out:
# Error caught: 'set' object does not support item assignment

# %%
set1={1,3,5,7,9,}

# %%
print(set1)
# Out:
# {1, 3, 5, 7, 9}

# %%
set2={2,3,5,8,10}

# %%
print(set2)
# Out:
# {2, 3, 5, 8, 10}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
set1.intersection(set2)
# Out:
# {3, 5}

# %% [markdown]
# **Operators and Conditional Statements**

# %%
score=10

# %%
score=int(input('enter the score 0 to 7:'))
if score >=0<=10:
  print("Above Average")
  print("Good effort! Keep practicing, there's room for improvement")


elif score <=4 <=7:
   print("Average")
   print("can do better next time")

else:
   score <4
   print("Below Average")
   print("Need to Improve your performance")
# Out:
# enter the score 0 to 7:10
# Above Average
# Good effort! Keep practicing, there's room for improvement
